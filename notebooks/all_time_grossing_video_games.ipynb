# %% [markdown]
# ##READ IN FROM DATA
# file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\your_file_name.csv'
# df = pd.read_csv(file_path)

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import html5lib
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\all_time_gross_table_html_raw.csv'
all_time_gross_read_in = pd.read_csv(file_path)

# %%
all_time_gross = all_time_gross_read_in

# %%
all_time_gross.head()
# Out:
#    Rank                   Title     Platform  Year Gross revenue (est. US$)  \
# 0  Rank                   Title     Platform  Year                  Nominal
# 1     1          Space Invaders   Multi-plat  1978          $13,930,000,000
# 2     2                 Pac-Man   Multi-plat  1980          $13,560,000,000
# 3     3  Dungeon Fighter Online  PC / Mobile  2005          $22,000,000,000
# 4     4       Street Fighter II   Multi-plat  1991          $10,857,000,000
#
#   Gross revenue (est. US$).1 Gross revenue (est. US$).2  \
# 0                      As of                        Ref
# 1                       2016                      [n 1]
# 2                       2016                      [n 2]
# 3                       2023                        [8]
# 4                       2016                        [9]
#
#   Gross revenue (est. US$).3        Genre
# 0                  Inflation        Genre
# 1            $30,000,000,000        Shmup
# ...

# %%
all_time_gross.columns=['Rank','Title','Platform','Year','Gross_Revenue', 'As_of', 'drop_me','Inflation_Adjusted','Genre']

# %%
all_time_gross = all_time_gross.drop(columns='drop_me')

# %%
all_time_gross = all_time_gross.drop(index=0)

# %%
all_time_gross = all_time_gross.drop(index=28)

# %%
all_time_gross.at[9,'Platform'] = 'PC'

# %%
all_time_gross.at[3,'Platform'] = 'PC'

# %%
all_time_gross.at[12,'Platform'] = 'Mobile'

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Puzzle RPG', 'Puzzle')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Sports sim', 'Sports')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Maze', 'Arcade')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Shmup', 'Arcade')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Fighting', 'MMORPG')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('AR', 'RPG')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('GCS / MMO', 'RPG')

# %% [markdown]
# all_time_gross['Genre'] = all_time_gross['Genre'].str.replace('Action RPG', 'RPG')

# %% [markdown]
# all_time_gross.at[4,'Genre'] = 'Fightnin'

# %%
all_time_gross.Genre.value_counts()
# Out:
# Genre
# MMORPG           5
# Platformer       4
# Battle royale    2
# MOBA             2
# Puzzle           2
# Shmup            1
# Action ADV       1
# Action RPG       1
# Fitness          1
# RPG              1
# Sports sim       1
# Sports           1
# Puzzle RPG       1
# Strategy         1
# Maze             1
# AR               1
# MMOFPS           1
# Fighting         1
# Beat 'em up      1
# GCS / MMO        1
# Name: count, dtype: int64

# %%
all_time_gross
# Out:
#    Rank                         Title    Platform  Year    Gross_Revenue  \
# 1     1                Space Invaders  Multi-plat  1978  $13,930,000,000
# 2     2                       Pac-Man  Multi-plat  1980  $13,560,000,000
# 3     3        Dungeon Fighter Online          PC  2005  $22,000,000,000
# 4     4             Street Fighter II  Multi-plat  1991  $10,857,000,000
# 5     5                      Fortnite  Multi-plat  2017  $20,000,000,000
# 6     6                Honor of Kings      Mobile  2015  $18,664,000,000
# 7     7                          PUBG  Multi-plat  2017  $17,831,000,000
# 8     8                       Lineage  Multi-plat  1998   $9,252,513,000
# 9     9             League of Legends          PC  2009  $15,251,000,000
# 10   10                     CrossFire          PC  2007  $13,088,000,000
# 11   11             World of Warcraft          PC  2004  $12,812,000,000
# 12   12              Candy Crush Saga      Mobile  2012  $12,000,000,000
# ...
