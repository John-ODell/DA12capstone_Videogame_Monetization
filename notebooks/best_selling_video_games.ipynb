# %% [markdown]
# ##READ IN FROM DATA file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\your_file_name.csv' df = pd.read_csv(file_path)

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import html5lib
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\best_selling_video_games_raw.csv'
best_selling_video_games_raw = pd.read_csv(file_path)

# %%
best_selling_video_games = best_selling_video_games_raw

# %%
best_selling_video_games = best_selling_video_games.drop(columns = 'Ref')

# %%
best_selling_video_games['General_Platform']=best_selling_video_games['Platform']

# %%
best_selling_video_games['Company_Platform']=best_selling_video_games['Platform']

# %%
best_selling_video_games
# Out:
#     Rank                                    Title    Platform  Year     Sales  \
# 0      1                               Wii Sports         Wii  2006  82900000
# 1      2                                     PUBG          PC  2017  67900000
# 2      3                      Mario Kart 8 Deluxe      Switch  2017  52000000
# 3      4      Pokémon Red / Green / Blue / Yellow    Game Boy  1996  45690000
# 4      5                                  Wii Fit         Wii  2007  43800000
# 5      6            Animal Crossing: New Horizons      Switch  2020  42210000
# 6      7                        Super Mario Bros.         NES  1985  40240000
# 7      8                           Mario Kart Wii         Wii  2008  37380000
# 8      9                                   Tetris    Game Boy  1989  35000000
# 9     10                        Wii Sports Resort         Wii  2009  33140000
# 10    11                                Minecraft          PC  2009  33010000
# 11    12               Super Smash Bros. Ultimate      Switch  2018  31090000
# 12    13                New Super Mario Bros. Wii         Wii  2009  30320000
# 13    14          Pokemon Gold / Silver / Crystal         GBC  1999  30120000
# 14    15                                  Pac-Man        BREW  2005  30000000
# 15    16  The Legend of Zelda: Breath of the Wild      Switch  2017  29810000
# 16    17                       Grand Theft Auto V         PS3  2013  29520000
# 17    18                                Duck Hunt         NES  1984  28300000
# 18    19                                 Wii Play         Wii  2006  28020000
# 19    20                   Pokémon Sword / Shield      Switch  2019  25820000
# 20    21                      Super Mario Odyssey      Switch  2017  25760000
# 21    22                       Pokémon Sun / Moon         3DS  2016  25450000
# 22    23       Pokémon Diamond / Pearl / Platinum          DS  2006  25270000
# 23    24                       Grand Theft Auto V         PS4  2013  24660000
# 24    25                        Kinect Adventures        X360  2010  24000000
# 25    26                               Nintendogs          DS  2005  23960000
# 26    27                            Mario Kart DS          DS  2005  23600000
# 27    28        Pokémon Ruby / Sapphire / Emerald         GBA  2002  23280000
# 28    29                       Grand Theft Auto V         PS3  2013  22950000
# 29    30                               Sonic Dash         iOS  2013  22600000
# 30    31                       Sonic the Hedgehog  Mega Drive  1991  22480000
# 31    32                 Pokémon Scarlet / Violet      Switch  2022  22100000
# 32    33                        Super Mario World        SNES  1990  20610000
# 33    34                               Spider-Man         PS4  2018  20000000
# 34    35                                Brain Age          DS  2005  19010000
# 35    36            Sonic & Sega All-Stars Racing         iOS  2011  16750000
# 36    37                              Angry Birds         iOS  2009  10000000
# 37    38                           Hitman: Sniper     Android  2015  10000000
# 38    39           Stickman Legends Offline Games     Android  2017  10000000
# 39    40             Shadow of Death: Dark Knight     Android  2019  10000000
# 40    41                               Sonic Jump         iOS  2013   8800000
#
#    General_Platform Company_Platform
# 0               Wii              Wii
# 1                PC               PC
# 2            Switch           Switch
# 3          Game Boy         Game Boy
# 4               Wii              Wii
# 5            Switch           Switch
# 6               NES              NES
# 7               Wii              Wii
# 8          Game Boy         Game Boy
# 9               Wii              Wii
# 10               PC               PC
# 11           Switch           Switch
# 12              Wii              Wii
# 13              GBC              GBC
# 14             BREW             BREW
# 15           Switch           Switch
# 16              PS3              PS3
# 17              NES              NES
# 18              Wii              Wii
# 19           Switch           Switch
# 20           Switch           Switch
# 21              3DS              3DS
# 22               DS               DS
# 23              PS4              PS4
# 24             X360             X360
# 25               DS               DS
# 26               DS               DS
# 27              GBA              GBA
# 28              PS3              PS3
# 29              iOS              iOS
# 30       Mega Drive       Mega Drive
# 31           Switch           Switch
# 32             SNES             SNES
# 33              PS4              PS4
# 34               DS               DS
# 35              iOS              iOS
# 36              iOS              iOS
# 37          Android          Android
# 38          Android          Android
# 39          Android          Android
# 40              iOS              iOS

# %%
best_selling_video_games.General_Platform.value_counts()
# Out:
# General_Platform
# Switch        7
# Wii           6
# DS            4
# iOS           4
# Android       3
# PS3           2
# PC            2
# NES           2
# PS4           2
# Game Boy      2
# GBC           1
# BREW          1
# X360          1
# GBA           1
# Mega Drive    1
# SNES          1
# 3DS           1
# Name: count, dtype: int64

# %%
mobile_dictionary = {'Andriod':'Mobile','iOS':'Mobile'}

# %%
handheld_dictionary = {'DS':'Handheld','Game Boy':'Handheld','GBC':'Handheld','GBA':'Handheld','3DS':'Handheld'}

# %%
console_dictionary = {'Switch':'Console','Wii':'Console','PS3':'Console','PS4':'Console','Mega Drive':'Console','SNES':'Console'}

# %%
nintendo_dictionary =  {'Switch':'Nintendo','Wii':'Nintendo','DS':'Nintendo','NES':'Nintendo','Game Boy':'Nintendo','GBC':'Nintendo','GBA':'Nintendo','SNES':'Nintendo','3DS':'Nintendo'}

# %%
sony_dictionary = {'PS3':'Sony','PS4':'Sony'}

# %%
microsoft_dictionary = {'XBOX':'Microsoft'}
