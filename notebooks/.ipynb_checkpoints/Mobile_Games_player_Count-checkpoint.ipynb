# %% [markdown]
# ##READ IN FROM DATA
# file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\your_file_name.csv'
# df = pd.read_csv(file_path)

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import html5lib
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
file_path = r'C:\Users\johnc\Desktop\DA12\Python\DA12capstone_Videogame_Monetization\data\player_count_mobile_games_raw.csv'
mobile_games_player_count = pd.read_csv(file_path)

# %%
mobile_games_player_count.head(1)
# Out:
#                Game           As of Player count[a]    Release date  \
# 0  Candy Crush Saga  March 24, 2023     500 million  April 12, 2012
#
#   Publisher(s) Ref.
# 0         King  [1]

# %% [markdown]
# the_tencent_list = {'Netmarble Japan':'Tencent Games','Supercell':'Tencent Games','SYBO Games':'Tencent Games','TiMi Studios / Tencent Games / Garena':'Tencent Games','Tencent games':'Tencent Games','MZ:Tencent Games'}

# %%
mobile_games_player_count_changed = mobile_games_player_count

# %%
mobile_games_player_count_changed.columns=['Game','Date_of_Count', 'Player_Count', 'Release_Date', 'Publishers','drop']

# %%
mobile_games_player_count_changed=mobile_games_player_count_changed.drop(columns='drop')

# %% [markdown]
# mobile_games_player_count_changed['Publishers']=mobile_games_player_count_changed['Publishers'].replace(the_tencent_list)

# %%
mobile_games_player_count_changed.Publishers.value_counts()
# Out:
# Publishers
# Playrix                                  4
# Tencent Games                            3
# Rovio Entertainment                      2
# Bandai Namco Entertainment               2
# Line Corporation                         2
# Nintendo                                 2
# Electronic Arts                          2
# Konami                                   2
# Disney Interactive                       1
# Blizzard Entertainment                   1
# thatgamecompany                          1
# Elex                                     1
# PONOS                                    1
# GungHo Online Entertainment              1
# King                                     1
# HoYoverse                                1
# Netmarble Japan                          1
# Aniplex / Type-Moon                      1
# KLab                                     1
# Game Insight                             1
# MZ                                       1
# Supercell                                1
# Colopl                                   1
# SYBO Games                               1
# Gametion Technologies Pvt Ltd            1
# TiMi Studios / Tencent Games / Garena    1
# InnerSloth                               1
# Minovate                                 1
# Sega                                     1
# Voodoo                                   1
# Tencent games                            1
# NetEase                                  1
# Serkan Özyılmaz                          1
# Youzu Interactive                        1
# Pixonic                                  1
# Wargaming                                1
# Gameloft                                 1
# EA Sports                                1
# Activision                               1
# Creative Mobile                          1
# dotGears                                 1
# Name: count, dtype: int64

# %%
mobile_games_player_count_changed.at[1,'Player_Count'] = '500 million'

# %%
mobile_games_player_count_changed.at[2,'Player_Count'] = '485 million'

# %%
mobile_games_player_count_changed.at[9,'Player_Count'] = '310 million'

# %%
mobile_games_player_count_changed.at[14,'Player_Count'] = '210 million'

# %%
mobile_games_player_count_changed.at[21,'Player_Count'] = '124 million'

# %%
mobile_games_player_count_changed.at[24,'Player_Count'] = '112 million'

# %%
mobile_games_player_count_changed.at[25,'Player_Count'] = '108 million'

# %%
mobile_games_player_count_changed.at[48,'Player_Count'] = '53 million'

# %%
mobile_games_player_count_changed.at[49,'Player_Count'] = '52 million'

# %%
mobile_games_player_count_changed.at[17,'Release_Date'] = 'April 16, 2018'

# %%
mobile_games_player_count_changed.at[7,'Release_Date'] = 'August 1, 2016'

# %%
mobile_games_player_count_changed.at[8,'Release_Date'] = 'August 1, 2017'

# %%
mobile_games_player_count_changed.at[9,'Release_Date'] = 'March 1, 2018'

# %%
mobile_games_player_count_changed.at[12,'Release_Date'] = 'November 1, 2017'

# %% [markdown]
# mobile_games_player_count_changed.at[13,'Release_Date'] = 'March 1, 2018'

# %%
mobile_games_player_count_changed.at[25,'Release_Date'] = 'December 1, 2017'

# %%
mobile_games_player_count_changed.at[26,'Release_Date'] = 'April 1, 2011'

# %%
mobile_games_player_count_changed.at[27,'Release_Date'] = 'March 1, 2015'

# %%
def extract(count):
    return int(count.split()[0])*1_000_000

# %%
mobile_games_player_count_changed['Player_Count_Int']=mobile_games_player_count_changed['Player_Count'].apply(extract)

# %%
mobile_games_player_count_changed['Release_Date_Datetime'] = pd.to_datetime(mobile_games_player_count_changed['Release_Date'])

# %%
mobile_games_player_count_changed.head(1)
# Out:
#                Game   Date_of_Count Player_Count    Release_Date Publishers  \
# 0  Candy Crush Saga  March 24, 2023  500 million  April 12, 2012       King
#
#    Player_Count_Int Release_Date_Datetime Publishers_Unmasked
# 0         500000000            2012-04-12                King

# %%
mobile_games_player_count_changed['Publishers_Unmasked']=mobile_games_player_count_changed['Publishers']

# %%
the_microsoft_list = {'King':'Microsoft', 'Blizzard Entertainment':'Microsoft', 'Activison':'Microsoft','Activision':'Microsoft'}

# %%
nintendo_list = {'Bandai Namco Entertainment':'Nintendo','Sega':'Nintendo','Rovio Entertainment':'Nintendo'}

# %%
the_tencent_list = {
    'Netmarble Japan': 'Tencent Games',
    'Supercell': 'Tencent Games',
    'SYBO Games': 'Tencent Games',
    'TiMi Studios / Tencent Games / Garena': 'Tencent Games',
    'Tencent games': 'Tencent Games',
    'MZ': 'Tencent Games'
}

# %%
Unmasked_Dictionary = {**the_microsoft_list,**nintendo_list,**the_tencent_list}

# %%
mobile_games_player_count_changed['Publishers_Unmasked']=mobile_games_player_count_changed['Publishers_Unmasked'].replace(Unmasked_Dictionary)

# %%
mobile_games_player_count_changed
# Out:
#                                 Game   Date_of_Count Player_Count  \
# 0                   Candy Crush Saga  March 24, 2023  500 million
# 1               Call of Duty: Mobile        May 2021  500 million
# 2                           Among Us   November 2020  485 million
# 3                         Mini World      April 2020  400 million
# 4       Dragon Ball Z: Dokkan Battle     August 2021  350 million
# 5                         Sonic Dash   February 2020  350 million
# 6                         Helix Jump   December 2018  334 million
# 7            Gardenscapes: New Acres        May 2020  324 million
# 8                         Homescapes        May 2020  312 million
# 9                        PUBG Mobile     August 2023  310 million
# 10                   Super Mario Run     August 2018  300 million
# 11                          Township        May 2020  274 million
# 12                        Knives Out  September 2018  250 million
# 13                     Angry Birds 2   December 2019  230 million
# 14   Honor of Kings / Arena of Valor   December 2017  210 million
# 15  QQ Speed Mobile / Speed Drifters    January 2020  200 million
# 16                           Fishdom        May 2020  173 million
# 17                           Rise Up   December 2018  162 million
# 18                   PES 2018 Mobile     August 2018  150 million
# 19                        War Robots    January 2020  150 million
# 20                    World of Tanks      March 2016  140 million
# 21                   Mario Kart Tour    October 2019  124 million
# 22                   Ice Age Village            2013  120 million
# 23           FIFA Mobile (now EA FC)    January 2018  113 million
# 24                    Subway Surfers       July 2019  110 million
# 25                      Tiao Yi Tiao    January 2018  108 million
# 26                       Drag Racing   February 2013  100 million
# 27             Junior Three Kingdoms    January 2018  100 million
# 50        May 24, 2013                               dotGears
# 51   February 28, 2014                       Line Corporation
#
#     Player_Count_Int Release_Date_Datetime            Publishers_Unmasked
# 0          500000000            2012-04-12                      Microsoft
# 1          500000000            2019-10-01                      Microsoft
# 2          485000000            2018-06-15                     InnerSloth
# 3          400000000            2015-12-26                       Minovate
# 4          350000000            2015-01-30                       Nintendo
# 5          350000000            2013-03-07                       Nintendo
# 6          334000000            2018-02-10                         Voodoo
# 7          324000000            2016-08-01                        Playrix
# 8          312000000            2017-08-01                        Playrix
# 9          310000000            2018-03-01                  Tencent Games
# 10         300000000            2016-12-15                       Nintendo
# 11         274000000            2012-02-24                        Playrix
# 12         250000000            2017-11-01                        NetEase
# 13         230000000            2015-07-30                       Nintendo
# 14         210000000            2015-11-26                  Tencent Games
# 15         200000000            2017-12-29                  Tencent Games
# 16         173000000            2008-06-18                        Playrix
# 17         162000000            2018-04-16                Serkan Özyılmaz
# 18         150000000            2017-09-12                         Konami
# 19         150000000            2014-04-14                        Pixonic
# 20         140000000            2010-08-12                      Wargaming
# 21         124000000            2019-09-25                       Nintendo
# 22         120000000            2012-04-05                       Gameloft
# 23         113000000            2016-10-01                      EA Sports
# 24         110000000            2012-05-24                  Tencent Games
# 25         108000000            2017-12-01                  Tencent Games
# 26         100000000            2011-04-01                Creative Mobile
# 27         100000000            2015-03-01              Youzu Interactive
# 28         100000000            2016-12-17  Gametion Technologies Pvt Ltd
# 29         100000000            2014-05-12                       Nintendo
# 30         100000000            2015-11-24                Electronic Arts
# 31         100000000            2014-07-14                         Colopl
# 32         100000000            2014-03-11                      Microsoft
# 33         100000000            2016-11-17                         Konami
# 34         100000000            2015-05-20                  Tencent Games
# 35         100000000            2019-07-18                thatgamecompany
# 36          90000000            2017-12-14                           Elex
# 37          84000000            2014-09-17                          PONOS
# 38          80000000            2014-01-29               Line Corporation
# 39          80000000            2012-02-20    GungHo Online Entertainment
# 40          80000000            2012-02-29                Electronic Arts
# 41          70000000            2012-03-01             Disney Interactive
# 42          65000000            2020-09-28                      HoYoverse
# 43          60000000            2012-02-13                       Nintendo
# 44          60000000            2016-02-05                  Tencent Games
# 45          57000000            2015-07-30            Aniplex / Type-Moon
# 46          55000000            2015-07-23                           KLab
# 47          55000000            2017-05-18                   Game Insight
# 48          53000000            2017-06-29                  Tencent Games
# 49          52000000            2016-03-02                  Tencent Games
# 50          50000000            2013-05-24                       dotGears
# 51          50000000            2014-02-28               Line Corporation

# %%
mobile_games_player_count_changed.Publishers_Unmasked.value_counts()
# Out:
# Publishers_Unmasked
# Tencent Games                    9
# Nintendo                         7
# Playrix                          4
# Microsoft                        3
# Electronic Arts                  2
# Konami                           2
# Line Corporation                 2
# GungHo Online Entertainment      1
# thatgamecompany                  1
# Elex                             1
# PONOS                            1
# HoYoverse                        1
# Disney Interactive               1
# Aniplex / Type-Moon              1
# KLab                             1
# Game Insight                     1
# Colopl                           1
# Youzu Interactive                1
# Gametion Technologies Pvt Ltd    1
# InnerSloth                       1
# Creative Mobile                  1
# EA Sports                        1
# Gameloft                         1
# Wargaming                        1
# Pixonic                          1
# Serkan Özyılmaz                  1
# NetEase                          1
# Voodoo                           1
# Minovate                         1
# dotGears                         1
# Name: count, dtype: int64
